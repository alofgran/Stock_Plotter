# %% [markdown]
# # __TDI 12-Day Program: Milestone Project__

# %%
import quandl                                              # import data from quandl website
import pandas as pd                                        # data manipulation
# import datetime                                            # gets current date
# from dateutil.relativedelta import relativedelta           # gets date minus one month
from bokeh.io import push_notebook, show, output_notebook  # updates plots dynamically
# from bokeh.layouts import row                              # 
from bokeh.plotting import figure                          # creates bokeh figure
output_notebook()                                          # outputs bokeh figures in Jupyter Notebook
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
# # This utilizes an up-to-date API in case its required by TDI

# import requests
# import io
# # Alpha Vantage
# api_key = '49ADEMYBSHAY4NKU'
# url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol='+t_symbol+'&datatype=csv&apikey='+api_key

#Get dates
# now = (datetime.date.today() + relativedelta(days =- 1)).strftime('%Y-%m-%d')
# month_back = (datetime.date.today() + relativedelta(months =- 1)).strftime('%Y-%m-%d')

# data = pd.read_csv(url)
# # Drop unneeded columns
# data = data.drop(columns = ['open', 'high', 'low', 'volume', 'close', 'dividend_amount', 'split_coefficient'])
# # Rename column header
# data.rename(columns={'timestamp':'date'}, inplace = True)
# # Shorten adj_close
# data.adjusted_close = round(data.adjusted_close, 2)

# # Set the index
# data = data.set_index('date')
# # Keep only the last month of data
# new_data = data[data['2019-08-11':'2019-09-12']]
# data
# # Plot

# %%
# Set up the API request including user input (trigger an error if ticker symbol is invalid)
quandl.ApiConfig.api_key = 'CD38JS9JqAdmdeio9JPW'

# Setup the ticker symbol input
t_symbol = 'AAPL'

data = quandl.get_table('WIKI/PRICES', ticker = t_symbol,
                        qopts = {'columns':['ticker', 'date', 'adj_close']},
                        date = {'gte': '2017-12-31', 'lte': '2018-01-31'}, 
                        paginate = True) #if not pandas, then numpy

# %%
data.info
# Out:
# <bound method DataFrame.info of      ticker       date  adj_close
# None
# 0      AAPL 2018-01-31     167.43
# 1      AAPL 2018-01-30     166.97
# 2      AAPL 2018-01-29     167.96
# 3      AAPL 2018-01-26     171.51
# 4      AAPL 2018-01-25     171.11
# 5      AAPL 2018-01-24     174.22
# 6      AAPL 2018-01-23     177.04
# 7      AAPL 2018-01-22     177.00
# 8      AAPL 2018-01-19     178.46
# 9      AAPL 2018-01-18     179.26
# 10     AAPL 2018-01-17     179.10
# 11     AAPL 2018-01-16     176.19
# 12     AAPL 2018-01-12     177.09
# 13     AAPL 2018-01-11     175.28
# 14     AAPL 2018-01-10     174.29
# 15     AAPL 2018-01-09     174.33
# 16     AAPL 2018-01-08     174.35
# 17     AAPL 2018-01-05     175.00
# 18     AAPL 2018-01-04     173.03
# 19     AAPL 2018-01-03     172.23
# 20     AAPL 2018-01-02     172.26>

# %%
data.head()
# Out:
#      ticker       date  adj_close
# None
# 0      AAPL 2018-01-31     167.43
# 1      AAPL 2018-01-30     166.97
# 2      AAPL 2018-01-29     167.96
# 3      AAPL 2018-01-26     171.51
# 4      AAPL 2018-01-25     171.11

# %% [markdown]
# ## Clean the data

# %%
# Shorten adj_close
data.adj_close = round(data.adj_close, 2)

# Set the index
data = data.set_index('date')

# Unstack ticker ticker column
cleaned = data.pivot(columns = 'ticker')
cleaned.head()
# Out:
#            adj_close
# ticker          AAPL
# date
# 2018-01-02    172.26
# 2018-01-03    172.23
# 2018-01-04    173.03
# 2018-01-05    175.00
# 2018-01-08    174.35

# %%
# Plot the data using bokeh (using the hover tool)

p = figure(plot_width = 500, plot_height = 400, x_axis_type='datetime', y_minor_ticks=2, tools='hover')
p.line(x = data.index, y = data.adj_close, line_width = 2, hover_color = 'red', hover_alpha = 0.6)

show(p)
# handle = show(p, notebook_handle=True) # handle - if realtime updates are needed/implemented
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-6663f036479b> in <module>
#       2
#       3 p = figure(plot_width = 500, plot_height = 400, x_axis_type='datetime', y_minor_ticks=2, tools='hover')
# ----> 4 p.line(x = data.index, y = data.adj_close, line_width = 2, hover_color = 'red', hover_alpha = 0.6)
#       5
#       6 show(p)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'adj_close'

# %%
data = pd.DataFrame([(1,2), (3, 4), (2, 5), (1, 4)])
# PLOT DATA
p = figure(plot_width = 500, plot_height = 400, y_minor_ticks=2)
p.line(x = data[0], y = data[1], line_width = 2)
show(p)
# Out:
#   <div class="bk-root" id="105fbed5-325f-4668-8b66-c5f75583880f" data-root-id="1631"></div>
